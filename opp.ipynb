# %%
class Animal:
    def __init__(self):
       self.name =input("Enter the name of the animal: ")
    def make_sound(self):
        sounds ={
            "dog": "woof",
            "cat": "meow",
            "wolf": "howl",
            "lion": "roar",
            "tiger": "growl",
            "leapord": "snarl",

        }
        
        return sounds.get(self.name.lower())
    def exists(self):
        known_animals = ["dog", "cat", "wolf", "lion", "tiger", "leapord"]
        return self.name.lower() in known_animals
    def append_animal(self, new_animal):
        known_animals = ["dog", "cat", "wolf", "lion", "tiger", "leapord"]
        if new_animal.lower() not in known_animals:
            known_animals.append(new_animal.lower())
            print(f"{new_animal} has been added to the list of known animals.")
        else:
            print(f"{new_animal} is already in the list of known animals.")
animal = Animal()
print(f"The sound of the {animal.name.lower()} is: {animal.make_sound()}")
#animal.exists()
animals = []
for _ in range(3):
    animal = Animal()
    animals.append(animal)
    print()
for animal in animals:    print(f"The sound of the {animal.name.lower()} is: {animal.make_sound()}")
# Out:
# The sound of the lion is: roar
# The sound of the tiger is: growl
# The sound of the cat is: meow
# The sound of the cow is: None
